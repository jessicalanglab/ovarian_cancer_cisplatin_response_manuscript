# %%
import pandas as pd
import json

# %%
depmap_data_folder = "../../data/public_data_sets/depmap_data"
counts_file = f"{depmap_data_folder}/gene_expression.csv" # TODO: Is this log2 counts or raw?
metadata_file = f"{depmap_data_folder}/models.csv"
parsed_metadata_file = f"{depmap_data_folder}/metadata_parsed.csv"

# %% [markdown]
# ### Load metadata

# %%
metadata = pd.read_csv(metadata_file, sep = ",")
metadata_parsed = metadata[metadata["OncotreeLineage"] == "Ovary/Fallopian Tube"]
display(metadata_parsed)
metadata_parsed.to_csv(parsed_metadata_file, sep = "\t", index = False)
# Out:
#          ModelID  PatientID CellLineName StrippedCellLineName DepmapModelType  \
# 0     ACH-000001  PT-gj46wT  NIH:OVCAR-3            NIHOVCAR3           HGSOC
# 11    ACH-000013  PT-gj46wT    ONCO-DG-1              ONCODG1           HGSOC
# 46    ACH-000048  PT-EehOTC     TOV-112D              TOV112D             EOV
# 89    ACH-000091  PT-kmyeHR         OV56                 OV56             SOC
# 101   ACH-000103  PT-gCHPXX       Caov-4                CAOV4           HGSOC
# ...          ...        ...          ...                  ...             ...
# 1611  ACH-002181  PT-B4cHwN      OVCA420              OVCA420             SOC
# 1612  ACH-002182  PT-SEFFqc      OVCA433              OVCA433             SOC
# 1613  ACH-002183  PT-P1CUUK        OVMIU                OVMIU           HGSOC
# 1828  ACH-002486  PT-pyZjZu       MES-OV                MESOV             SOC
# 1838  ACH-002524  PT-itoB60      SNU-251               SNU251             EOV
#
# ...
