# %%
import os
import pandas as pd

local_EGAD_fastq_folder = "../../data/public_data_sets/EGAD00001006441/RNAseq_data"
linstat_EGAD_fastq_folder = "/project/rnaseq/EGAD00001006441"
rnaseq_samplesheet_path = "../../data/public_data_sets/EGAD00001006441/rnaseq_samplesheet.csv"

# %% [markdown]
# ## Create RNA-seq sample sheet

# %%
fastq_file_info = pd.DataFrame(columns=["sample_name", "lane_number", "read_number", "relative_path", "absolute_path"])

# Loop over the folders inside EGAD_fastq_folder
for sub_folder in os.listdir(local_EGAD_fastq_folder):
    # Check if the folder is a directory
    if os.path.isdir(os.path.join(local_EGAD_fastq_folder, sub_folder)):
        # Loop over the files inside the folder
        for file in os.listdir(os.path.join(local_EGAD_fastq_folder, sub_folder)):
            # Check if the file is a fastq file
            if file.endswith(".fastq.gz"):
                rel_path = os.path.join(local_EGAD_fastq_folder, sub_folder, file)
                abs_path = os.path.join(linstat_EGAD_fastq_folder, sub_folder, file)

                # Parse sample info out of filename
                # Format of filename: samplename-Carey_lanenumber_readnumber_001.fastq.gz
                filename = file.split(".")[0]
                fastq_file_info.loc[len(fastq_file_info)] = {
                    "sample_name": filename.split("-")[0],
                    "lane_number": filename.split("_")[2],
                    "read_number": filename.split("_")[3],
                    "relative_path": rel_path,
                    "absolute_path": abs_path
                }
fastq_file_info = fastq_file_info.sort_values(by=["sample_name", "lane_number", "read_number"])
display(fastq_file_info)
# Out:
#    sample_name lane_number read_number  \
# 33         CL1        L001          R1
# 13         CL1        L001          R2
# 20         CL1        L002          R1
# 51         CL1        L002          R2
# 17         CL1        L003          R1
# ..         ...         ...         ...
# 38         CL7        L002          R2
# 58         CL7        L003          R1
# 37         CL7        L003          R2
# 8          CL7        L004          R1
# 9          CL7        L004          R2
#
#                                         relative_path  \
# 33  ../../data/public_data_sets/EGAD00001006441/RN...
# 13  ../../data/public_data_sets/EGAD00001006441/RN...
# 20  ../../data/public_data_sets/EGAD00001006441/RN...
# 51  ../../data/public_data_sets/EGAD00001006441/RN...
# 17  ../../data/public_data_sets/EGAD00001006441/RN...
# ..                                                ...
# 38  ../../data/public_data_sets/EGAD00001006441/RN...
# 58  ../../data/public_data_sets/EGAD00001006441/RN...
# 37  ../../data/public_data_sets/EGAD00001006441/RN...
# 8   ../../data/public_data_sets/EGAD00001006441/RN...
# 9   ../../data/public_data_sets/EGAD00001006441/RN...
#
#                                         absolute_path
# 33  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 13  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 20  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 51  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 17  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# ..                                                ...
# 38  /project/rnaseq/EGAD00001006441/EGAF0000471983...
# 58  /project/rnaseq/EGAD00001006441/EGAF0000471984...
# 37  /project/rnaseq/EGAD00001006441/EGAF0000471984...
# 8   /project/rnaseq/EGAD00001006441/EGAF0000471984...
# 9   /project/rnaseq/EGAD00001006441/EGAF0000471984...
#
# [64 rows x 5 columns]

# %%
# Validate that each unique (sample_name, lane_number) pair has exactly 2 reads
grouped = fastq_file_info.groupby(['sample_name', 'lane_number'])['read_number'].apply(set)
invalid_groups = grouped[grouped.apply(lambda x: x != {"R1", "R2"})]
assert len(invalid_groups) == 0, f"The following (sample_name, lane_number) pairs do not have exactly one 'R1' and one 'R2': {invalid_groups}"

# Reshape the dataframe to have one row per (sample_lane_number) pair
pivot_df = fastq_file_info.pivot(index=['sample_name', 'lane_number'], columns='read_number', values='absolute_path')
pivot_df.reset_index(inplace=True)

# Format rnaseq samplesheet
rnaseq_samplesheet = pd.DataFrame({
    "sample": pivot_df["sample_name"],
    "fastq_1": pivot_df["R1"],
    "fastq_2": pivot_df["R2"],
    "strandedness": "auto"
})

display(rnaseq_samplesheet)

# Write rnaseq samplesheet to file
rnaseq_samplesheet.to_csv(rnaseq_samplesheet_path, index=False)
# Out:
#    sample                                            fastq_1  \
# 0     CL1  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 1     CL1  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 2     CL1  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 3     CL1  /project/rnaseq/EGAD00001006441/EGAF0000471981...
# 4    CL10  /project/rnaseq/EGAD00001006441/EGAF0000471978...
# 5    CL10  /project/rnaseq/EGAD00001006441/EGAF0000471978...
# 6    CL10  /project/rnaseq/EGAD00001006441/EGAF0000471978...
# 7    CL10  /project/rnaseq/EGAD00001006441/EGAF0000471978...
# 8    CL14  /project/rnaseq/EGAD00001006441/EGAF0000471978...
# 9    CL14  /project/rnaseq/EGAD00001006441/EGAF0000471979...
# 10   CL14  /project/rnaseq/EGAD00001006441/EGAF0000471979...
# 11   CL14  /project/rnaseq/EGAD00001006441/EGAF0000471979...
# 12   CL15  /project/rnaseq/EGAD00001006441/EGAF0000471979...
# 13   CL15  /project/rnaseq/EGAD00001006441/EGAF0000471979...
# 14   CL15  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 15   CL15  /project/rnaseq/EGAD00001006441/EGAF0000471980...
# 16    CL2  /project/rnaseq/EGAD00001006441/EGAF0000471981...
# 17    CL2  /project/rnaseq/EGAD00001006441/EGAF0000471981...
# 18    CL2  /project/rnaseq/EGAD00001006441/EGAF0000471981...
# 19    CL2  /project/rnaseq/EGAD00001006441/EGAF0000471981...
# 20    CL3  /project/rnaseq/EGAD00001006441/EGAF0000471982...
# 21    CL3  /project/rnaseq/EGAD00001006441/EGAF0000471982...
# 22    CL3  /project/rnaseq/EGAD00001006441/EGAF0000471982...
# 23    CL3  /project/rnaseq/EGAD00001006441/EGAF0000471982...
# 24    CL6  /project/rnaseq/EGAD00001006441/EGAF0000471982...
# 25    CL6  /project/rnaseq/EGAD00001006441/EGAF0000471983...
# 26    CL6  /project/rnaseq/EGAD00001006441/EGAF0000471983...
# 27    CL6  /project/rnaseq/EGAD00001006441/EGAF0000471983...
# 28    CL7  /project/rnaseq/EGAD00001006441/EGAF0000471983...
# 29    CL7  /project/rnaseq/EGAD00001006441/EGAF0000471983...
# 30    CL7  /project/rnaseq/EGAD00001006441/EGAF0000471984...
# 31    CL7  /project/rnaseq/EGAD00001006441/EGAF0000471984...
#
#                                               fastq_2 strandedness
# 0   /project/rnaseq/EGAD00001006441/EGAF0000471980...         auto
# 1   /project/rnaseq/EGAD00001006441/EGAF0000471980...         auto
# 2   /project/rnaseq/EGAD00001006441/EGAF0000471980...         auto
# 3   /project/rnaseq/EGAD00001006441/EGAF0000471981...         auto
# 4   /project/rnaseq/EGAD00001006441/EGAF0000471978...         auto
# 5   /project/rnaseq/EGAD00001006441/EGAF0000471978...         auto
# 6   /project/rnaseq/EGAD00001006441/EGAF0000471978...         auto
# 7   /project/rnaseq/EGAD00001006441/EGAF0000471978...         auto
# 8   /project/rnaseq/EGAD00001006441/EGAF0000471978...         auto
# 9   /project/rnaseq/EGAD00001006441/EGAF0000471979...         auto
# 10  /project/rnaseq/EGAD00001006441/EGAF0000471979...         auto
# 11  /project/rnaseq/EGAD00001006441/EGAF0000471979...         auto
# 12  /project/rnaseq/EGAD00001006441/EGAF0000471979...         auto
# 13  /project/rnaseq/EGAD00001006441/EGAF0000471979...         auto
# 14  /project/rnaseq/EGAD00001006441/EGAF0000471980...         auto
# 15  /project/rnaseq/EGAD00001006441/EGAF0000471980...         auto
# 16  /project/rnaseq/EGAD00001006441/EGAF0000471981...         auto
# 17  /project/rnaseq/EGAD00001006441/EGAF0000471981...         auto
# 18  /project/rnaseq/EGAD00001006441/EGAF0000471981...         auto
# 19  /project/rnaseq/EGAD00001006441/EGAF0000471981...         auto
# 20  /project/rnaseq/EGAD00001006441/EGAF0000471982...         auto
# 21  /project/rnaseq/EGAD00001006441/EGAF0000471982...         auto
# 22  /project/rnaseq/EGAD00001006441/EGAF0000471982...         auto
# 23  /project/rnaseq/EGAD00001006441/EGAF0000471982...         auto
# 24  /project/rnaseq/EGAD00001006441/EGAF0000471982...         auto
# 25  /project/rnaseq/EGAD00001006441/EGAF0000471983...         auto
# 26  /project/rnaseq/EGAD00001006441/EGAF0000471983...         auto
# 27  /project/rnaseq/EGAD00001006441/EGAF0000471983...         auto
# 28  /project/rnaseq/EGAD00001006441/EGAF0000471983...         auto
# 29  /project/rnaseq/EGAD00001006441/EGAF0000471983...         auto
# 30  /project/rnaseq/EGAD00001006441/EGAF0000471984...         auto
# 31  /project/rnaseq/EGAD00001006441/EGAF0000471984...         auto

# %% [markdown]
# ## Run rnaseq pipeline
#
# ```{sh}
# ./nextflow run nf-core/rnaseq \
#     --input /project9/rnaseq/EGAD00001006441/rnaseq_samplesheet.csv \
#     --outdir EGAD00001006441 \
#     -N -bg \
#     --igenomes_base /project/rnaseq/ngi-igenomes/igenomes \
#     --genome GRCh38
# ```
